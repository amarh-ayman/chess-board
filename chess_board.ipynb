# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
class ChessBoard:
    def __init__(self,row=8,col=8):
        self.board=np.zeros((row,col,4))
        self.chBoard()
        self.red=[]
        self.blue=[]
        self.render()

    def chBoard(self): 
        self.board[::2 ,::2]=[0,0,0,1]
        self.board[1::2,1::2]=[0,0,0,1]

    def add_red(self ,row,column ,opacity=1):
        self.board[row][column]=[1,0.2,0,opacity]
        self.red.append([row,column])

    def add_blue(self ,row,column,opacity=1):
        self.board[row][column]=[0,1,1,opacity] 
        self.blue.append([row,column])

    def render(self):
        plt.imshow(self.board) 

    def is_under_attack(self):
        try:
            # if equal then assertion will make an error so that the except
            assert self.blue[1] != self.red[1]
            assert self.blue[0] != self.red[0]
            assert abs(self.red[0]-self.blue[0])!=abs(self.red[1]-self.blue[1])
        except:    
            print('under attack\n')

# %%
chess=ChessBoard()
chess.add_red(0,5)
chess.add_blue(2,7)
chess.render()
chess.is_under_attack()
# Out:
# under attack

# %%
class StretchGoals(ChessBoard):
    def __init__(self):
        ChessBoard.__init__(self,16,16)

    def is_under_attack(self):
            try:
                for index,item in enumerate(self.blue):
                    assert (item[0]!=self.red[:,0]).any()
                    assert (item[0]!=b[:,0]).any()
                    assert (abs(item[0]-b[:,0])!=abs(item[1]-b[:,1])).any()
            except :
                    print('under attack')

# %%
s=StretchGoals()
s.add_blue(1,2,0.5)
s.add_blue(6,5,0.5)
s.add_blue(10,10,0.5)
s.add_blue(15,7,0.5)

s.add_red(10,2,0.5)
s.add_red(1,15,0.5)
s.add_red(0,4,0.5)
s.add_red(12,7,0.5)
s.render()
s.is_under_attack()
# Out:
# under attack
